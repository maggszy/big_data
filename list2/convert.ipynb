# %%
# from sqlalchemy import create_engine
import pandas as pd
import sqlite3
import csv
from operator import itemgetter

# %%
# NIEWAŻNE
#  conn = sqlite3.connect('ServiceRequest.db') #connect to SQLite database
# cursor = conn.cursor()
# # cursor.execute("DROP TABLE IF EXISTS servise_info;")

# cursor.execute('''CREATE TABLE IF NOT EXISTS service_info (
#                     unique_key INTEGER,
#                     created_date NUMERIC,
#                     closed_date NUMERIC,
#                     agency TEXT,
#                     agency_name TEXT,
#                     complaint_type TEXT,
#                     descriptor TEXT, 
#                     location_type TEXT,
#                     incident_zip REAL,
#                     incident_address TEXT,
#                     street_name TEXT, 
#                     cross_street1 TEXT, 
#                     cross_street2 TEXT, 
#                     intersection_street1 TEXT,
#                     intersection_street2 TEXT,
#                     address_type TEXT,
#                     city TEXT, 
#                     landmark REAL,
#                     facility_type TEXT, 
#                     status TEXT,
#                     due_date NUMERIC, 
#                     resolution_description TEXT,
#                     resolution_action_updated_date NUMERIC, 
#                     community_board TEXT, 
#                     bbl REAL, 
#                     borough TEXT, 
#                     x_coordinate_state_plane REAL, 
#                     y_coordinate_state_plane REAL, 
#                     open_data_channel_type TEXT, 
#                     park_facility_name TEXT, 
#                     park_borough TEXT, 
#                     vehicle_type TEXT,
#                     taxi_company_borough TEXT, 
#                     taxi_pick_up_location TEXT, 
#                     bridge_highway_name TEXT, 
#                     bridge_highway_direction TEXT, 
#                     road_ramp TEXT,
#                     bridge_highway_segment TEXT, 
#                     latitude REAL, 
#                     longitude REAL, 
#                     location TEXT
#                 )''')


# cols = ['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name', 'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip', 'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2', 'Intersection Street 1', 'Intersection Street 2', 'Address Type', 'City', 'Landmark', 'Facility Type', 'Status', 'Due Date', 'Resolution Description', 'Resolution Action Updated Date', 'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)', 'Open Data Channel Type', 'Park Facility Name', 'Park Borough', 'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment', 'Latitude', 'Longitude', 'Location']
# chunksize = 10000

# # parse csv file and populate db in chunks
# with open("311_Service_Requests_from_2010_to_Present_20240331.csv") as f:
#     reader = csv.DictReader(f)

#     chunk = []
#     for i, row in enumerate(reader): 

#         if i % chunksize == 0 and i > 0:
#             conn.executemany(
#                 """
#                 INSERT INTO service_info
#                     VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
#                 """, chunk
#             )
#             chunk = []

#         items = itemgetter(*cols)(row)
#         chunk.append(items)

# conn.commit()
# conn.close()
# #time: 16m 51.5s
# # time: 17m 52.6s

# %%
# %%time
conn = sqlite3.connect('ServiceRequest.db') #connect to SQLite database
cursor = conn.cursor()
cursor.execute("DROP TABLE IF EXISTS servise_info;")

cursor.execute('''CREATE TABLE IF NOT EXISTS service_info (
                    unique_key INTEGER,
                    created_date NUMERIC,
                    closed_date NUMERIC,
                    agency TEXT,
                    agency_name TEXT,
                    complaint_type TEXT,
                    descriptor TEXT, 
                    location_type TEXT,
                    incident_zip REAL,
                    incident_address TEXT,
                    street_name TEXT, 
                    cross_street1 TEXT, 
                    cross_street2 TEXT, 
                    intersection_street1 TEXT,
                    intersection_street2 TEXT,
                    address_type TEXT,
                    city TEXT, 
                    landmark TEXT,
                    facility_type TEXT, 
                    status TEXT,
                    due_date NUMERIC, 
                    resolution_description TEXT,
                    resolution_action_updated_date NUMERIC, 
                    community_board TEXT, 
                    bbl REAL, 
                    borough TEXT, 
                    x_coordinate_state_plane REAL, 
                    y_coordinate_state_plane REAL, 
                    open_data_channel_type TEXT, 
                    park_facility_name TEXT, 
                    park_borough TEXT, 
                    vehicle_type TEXT,
                    taxi_company_borough TEXT, 
                    taxi_pick_up_location TEXT, 
                    bridge_highway_name TEXT, 
                    bridge_highway_direction TEXT, 
                    road_ramp TEXT,
                    bridge_highway_segment TEXT, 
                    latitude REAL, 
                    longitude REAL, 
                    location TEXT
                )''')


cols = ['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name', 'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip', 'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2', 'Intersection Street 1', 'Intersection Street 2', 'Address Type', 'City', 'Landmark', 'Facility Type', 'Status', 'Due Date', 'Resolution Description', 'Resolution Action Updated Date', 'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)', 'Open Data Channel Type', 'Park Facility Name', 'Park Borough', 'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment', 'Latitude', 'Longitude', 'Location']
chunksize = 10000

# parse csv file and populate db in chunks
with open("311_Service_Requests_from_2010_to_Present_20240331.csv") as f:
    reader = csv.DictReader(f)

    chunk = []
    # for i, row in enumerate(reader, start=1): 
    for row in reader: 

        items = itemgetter(*cols)(row)
        chunk.append(items)

        if len(chunk) == chunksize:
            conn.executemany(
                """
                INSERT INTO service_info
                    VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
                """, chunk
            )
            chunk = []
        
    if chunk:
        conn.executemany(
            """
            INSERT INTO service_info
                VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
            """, chunk
        )

conn.commit()
conn.close()
# time: 20min32.0s
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:59
#
# File c:\Users\Huawei\anaconda3\envs\BData\lib\csv.py:111, in DictReader.__next__(self)
#     108 if self.line_num == 0:
#     109     # Used only for its side effect.
#     110     self.fieldnames
# --> 111 row = next(self.reader)
#     112 self.line_num = self.reader.line_num
#     114 # unlike the basic reader, we prefer not to return blanks,
#     115 # because we will typically wind up with a dict full of None
#     116 # values
#
# File c:\Users\Huawei\anaconda3\envs\BData\lib\codecs.py:319, in BufferedIncrementalDecoder.decode(self, input, final)
#     314 def _buffer_decode(self, input, errors, final):
#     315     # Overwrite this method in subclasses: It must decode input
#     316     # and return an (output, length consumed) tuple
#     317     raise NotImplementedError
# ...

# %%
conn = sqlite3.connect('ServiceRequest.db') #connect to SQLite database
cursor = conn.cursor()

# %%
# %%time
res = cursor.execute("""SELECT complaint_type, COUNT(complaint_type) AS amount FROM service_info
                        GROUP BY complaint_type
                        ORDER BY amount DESC;
                    """)
# CPU times: total: 1min 5s
# Wall time: 1min 15s
# Out:
# CPU times: total: 1min 5s
# Wall time: 1min 15s

# %%
res.fetchall()
# Out:
# [('Noise - Residential', 3321134),
#  ('Illegal Parking', 2432161),
#  ('HEAT/HOT WATER', 2200209),
#  ('Blocked Driveway', 1554908),
#  ('Street Condition', 1253180),
#  ('Noise - Street/Sidewalk', 1179882),
#  ('Street Light Condition', 1135776),
#  ('Request Large Bulky Item Collection', 1073753),
#  ('PLUMBING', 934583),
#  ('HEATING', 887869),
#  ('Water System', 881222),
#  ('UNSANITARY CONDITION', 843842),
#  ('Noise', 682799),
#  ('General Construction/Plumbing', 653729),
#  ('Traffic Signal Condition', 594139),
#  ('Noise - Commercial', 590918),
#  ('PAINT/PLASTER', 559044),
#  ('Noise - Vehicle', 508056),
#  ('GENERAL CONSTRUCTION', 500821),
#  ('Sewer', 488888),
#  ('Damaged Tree', 447693),
#  ('Rodent', 429642),
#  ('Dirty Conditions', 417001),
#  ('ELECTRIC', 409805),
#  ('Derelict Vehicles', 397270),
#  ('Sanitation Condition', 383019),
#  ('DOOR/WINDOW', 363733),
#  ('PAINT - PLASTER', 361228),
#  ('Sidewalk Condition', 352932),
#  ('Building/Use', 346078),
# ...

# %%
# %%time
res2 = cursor.execute("""SELECT borough, complaint_type, COUNT(complaint_type) AS amount FROM service_info
                        GROUP BY borough, complaint_type
                        ORDER BY amount DESC;
                    """)

# %%
res2.fetchall()
# Out:
# [('BRONX', 'Noise - Residential', 971018),
#  ('BROOKLYN', 'Noise - Residential', 915720),
#  ('BROOKLYN', 'Illegal Parking', 881285),
#  ('BRONX', 'HEAT/HOT WATER', 747972),
#  ('QUEENS', 'Illegal Parking', 742041),
#  ('MANHATTAN', 'Noise - Residential', 679357),
#  ('QUEENS', 'Noise - Residential', 657428),
#  ('BROOKLYN', 'HEAT/HOT WATER', 637617),
#  ('QUEENS', 'Blocked Driveway', 631412),
#  ('BROOKLYN', 'Blocked Driveway', 571850),
#  ('MANHATTAN', 'HEAT/HOT WATER', 496125),
#  ('MANHATTAN', 'Noise - Street/Sidewalk', 439060),
#  ('BROOKLYN', 'Request Large Bulky Item Collection', 399299),
#  ('QUEENS', 'Street Condition', 390884),
#  ('QUEENS', 'Request Large Bulky Item Collection', 388581),
#  ('MANHATTAN', 'Illegal Parking', 354428),
#  ('BRONX', 'Illegal Parking', 348524),
#  ('BROOKLYN', 'Street Condition', 343984),
#  ('QUEENS', 'Street Light Condition', 333421),
#  ('MANHATTAN', 'Noise', 310268),
#  ('BRONX', 'Noise - Street/Sidewalk', 303463),
# ...

# %%
# %%time
res3 = cursor.execute("""SELECT agency, complaint_type, COUNT(complaint_type) AS amount FROM service_info
                        GROUP BY agency, complaint_type
                        ORDER BY amount DESC;
                    """)
# CPU times: total: 1min 34s
# Wall time: 1min 44s
# Out:
# CPU times: total: 1min 34s
# Wall time: 1min 44s

# %%
res3.fetchall()
# Out:
# [('NYPD', 'Noise - Residential', 3321132),
#  ('NYPD', 'Illegal Parking', 2432159),
#  ('HPD', 'HEAT/HOT WATER', 2200209),
#  ('NYPD', 'Blocked Driveway', 1554908),
#  ('DOT', 'Street Condition', 1253061),
#  ('NYPD', 'Noise - Street/Sidewalk', 1179880),
#  ('DOT', 'Street Light Condition', 1135620),
#  ('DSNY', 'Request Large Bulky Item Collection', 1073753),
#  ('HPD', 'PLUMBING', 934583),
#  ('HPD', 'HEATING', 887869),
#  ('DEP', 'Water System', 880532),
#  ('HPD', 'UNSANITARY CONDITION', 843842),
#  ('DEP', 'Noise', 682799),
#  ('DOB', 'General Construction/Plumbing', 653729),
#  ('DOT', 'Traffic Signal Condition', 594137),
#  ('NYPD', 'Noise - Commercial', 590918),
#  ('HPD', 'PAINT/PLASTER', 559044),
#  ('NYPD', 'Noise - Vehicle', 508056),
#  ('HPD', 'GENERAL CONSTRUCTION', 500821),
#  ('DEP', 'Sewer', 488551),
#  ('DPR', 'Damaged Tree', 447691),
#  ('DOHMH', 'Rodent', 429642),
#  ('DSNY', 'Dirty Conditions', 417001),
#  ('HPD', 'ELECTRIC', 409805),
# ...

# %%
conn.close()

# %% [markdown]
# # QUERY TUNING

# %%
conn = sqlite3.connect('ServiceRequest.db') #connect to SQLite database
cursor = conn.cursor()

# %%
# checking if there is indexing on the 'complaint_type' column
qr = cursor.execute("""SELECT name, sql
                    FROM sqlite_master
                    WHERE type='index' AND tbl_name='service_info' AND sql LIKE '%complaint_type%';
               """)

# %%
qr.fetchall()
# Out:
# [('idx_complaint_type',
#   'CREATE INDEX idx_complaint_type ON service_info (complaint_type)'),
#  ('idx_bor_compl_type',
#   'CREATE INDEX idx_bor_compl_type ON service_info (borough,complaint_type)'),
#  ('idx_agency_compl_type',
#   'CREATE INDEX idx_agency_compl_type ON service_info (agency,complaint_type)')]

# %%
qr2 = cursor.execute("CREATE INDEX idx_complaint_type ON service_info (complaint_type);")

# %%
# %%time
res_eff = cursor.execute("""SELECT complaint_type, COUNT(complaint_type) AS amount FROM service_info
                        GROUP BY complaint_type
                        ORDER BY amount DESC;
                    """)
# CPU times: total: 5.14 s
# Wall time: 5.65 s

#from CPU 1min 5s --> 5.14s
# Out:
# CPU times: total: 5.14 s
# Wall time: 5.65 s

# %%
# for improving second query
qr3 = cursor.execute("CREATE INDEX idx_bor_compl_type ON service_info (borough,complaint_type);")

# %%
# %%time
res2_eff = cursor.execute("""SELECT borough, complaint_type, COUNT(complaint_type) AS amount FROM service_info
                        GROUP BY borough, complaint_type
                        ORDER BY amount DESC;
                    """)
# CPU times: total: 7.17 s
# Wall time: 7.89 s

# from  ok. 2min --> 7.17s
# Out:
# CPU times: total: 7.17 s
# Wall time: 7.89 s

# %%
#improving third query
qr4 = cursor.execute("CREATE INDEX idx_agency_compl_type ON service_info (agency,complaint_type);")

# %%
# %%time
res3_eff = cursor.execute("""SELECT agency, complaint_type, COUNT(complaint_type) AS amount FROM service_info
                        GROUP BY agency, complaint_type
                        ORDER BY amount DESC;
                    """)

# CPU times: total: 6.61 s
# Wall time: 7.1 s  
                  
# from 1min 34s --> 6.61s
# Out:
# CPU times: total: 6.61 s
# Wall time: 7.1 s
